# %% [markdown]
# <a href="https://colab.research.google.com/github/godqhrgo7849/python/blob/master/Code_ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 나의 첫 딥러닝: ' 10장 폐암 수술 환자의 생존율 예측' 코드 미리보기

# %%
# 환경 준비
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# %%
# 데이터 준비
# !git clone https://github.com/taehojo/data.git

Data_set = np.loadtxt("./data/ThoraricSurgery3.csv", delimiter=",")
X = Data_set[:,0:16]
y = Data_set[:,16]
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.

# %%
# 구조 결정
model = Sequential()
model.add(Dense(30,input_dim=16,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#모델 실행
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history = model.fit(X,y, epochs=5,batch_size=16)
# Out:
# Epoch 1/5
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1511 - loss: 10.7879
# Epoch 2/5
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2170 - loss: 3.0813
# Epoch 3/5
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8511 - loss: 0.4973
# Epoch 4/5
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8511 - loss: 0.4894
# Epoch 5/5
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8511 - loss: 0.4753
